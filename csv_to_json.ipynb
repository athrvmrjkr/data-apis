# %%
import pandas as pd

# %%
df1 = pd.read_csv('./data/customer_data.csv')
df2 = pd.read_csv('./data/ecommerce_customer_data.csv')

# %%
df1.to_json(
    './data/customer_data.json',
    orient='records',
    date_format='iso'
)

df2.to_json(
    './data/ecommerce_customer_data.json',
    orient='records',
    date_format='iso'
)
